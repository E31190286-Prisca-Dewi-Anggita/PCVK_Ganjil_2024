# %% [markdown]
# <a href="https://colab.research.google.com/github/E31190286-Prisca-Dewi-Anggita/PCVK_Ganjil_2024/blob/main/Modul7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2 as cv
import math
from google.colab.patches import cv2_imshow
from PIL import Image as im

# %%
def convolution2d(image, kernel, stride, padding):
    # Function implementation here
    pass  # Remove this line when you implement the function

# Load and process the image
img = cv.imread('/content/drive/MyDrive/Classroom/download.jpg')
if img is not None:
    img_gray = cv.cvtColor(img, cv.COLOR_BGR2GRAY)
else:
    print("Error: Could not load image.")
    # Handle the error appropriately

# Define the sharpening kernel
kernel_sharpen = np.array([[0,-1,0],
                           [-1,5,-1],
                           [0,-1,0]])

# Call convolution2d only if img_gray is defined
if 'img_gray' in locals():
    convolution2d(img_gray, kernel_sharpen, 1, 2)
else:
    print("Error: img_gray is not defined.")

# %%
convolution2d(img_gray, kernel_sharpen, 1, 2)

# %%
# Import pustaka yang diperlukan
import cv2
import numpy as np
import matplotlib.pyplot as plt
import math

# Fungsi untuk menampilkan gambar hasil filter
def show_image_with_filter(image, title):
    plt.figure(figsize=(5,5))
    plt.imshow(image, cmap='gray')
    plt.title(title)
    plt.axis('off')
    plt.show()

# Baca gambar dari file atau upload gambar
image = cv2.imread('/content/drive/MyDrive/Classroom/download.jpg', cv2.IMREAD_GRAYSCALE)

# Kernel Sharpen
sharpen_kernel = np.array([[ 0, -1,  0],
                           [-1,  5, -1],
                           [ 0, -1,  0]])

# Kernel Emboss
emboss_kernel = np.array([[-2, -1,  0],
                          [-1,  1,  1],
                          [ 0,  1,  2]])

# Kernel Sobel (Left Sobel)
sobel_kernel = np.array([[ 1,  0, -1],
                         [ 2,  0, -2],
                         [ 1,  0, -1]])

# Kernel Prewitt Edge Detection
prewitt_kernel = np.array([[-1, -1, -1],
                           [ 0,  0,  0],
                           [ 1,  1,  1]])

# Kernel 5x5 Gaussian Blur
gaussian_kernel = np.array([[1,  4,  6,  4, 1],
                            [4, 16, 24, 16, 4],
                            [6, 24, 36, 24, 6],
                            [4, 16, 24, 16, 4],
                            [1,  4,  6,  4, 1]]) / 256

# Fungsi untuk generate kernel Gaussian 21x21
def generate_gaussian_kernel_21x21():
    kernel_size = 21
    sigma = math.sqrt(kernel_size)
    gaussian_kernel = cv2.getGaussianKernel(kernel_size, sigma)
    gauss_kernel = gaussian_kernel @ gaussian_kernel.T
    return gauss_kernel

# Generate 21x21 Gaussian kernel
gaussian_kernel_21 = generate_gaussian_kernel_21x21()

# Terapkan filter sharpen
sharpened_image = cv2.filter2D(image, -1, sharpen_kernel)
show_image_with_filter(sharpened_image, 'Sharpen')

# Terapkan filter emboss
embossed_image = cv2.filter2D(image, -1, emboss_kernel)
show_image_with_filter(embossed_image, 'Emboss')

# Terapkan Sobel filter (Left Sobel Edge Detection)
sobel_image = cv2.filter2D(image, -1, sobel_kernel)
show_image_with_filter(sobel_image, 'Left Sobel Edge Detection')

# Terapkan Prewitt Edge Detection
prewitt_image = cv2.filter2D(image, -1, prewitt_kernel)
show_image_with_filter(prewitt_image, 'Prewitt Edge Detection')

# Terapkan 5x5 Gaussian Blur
gaussian_blur_5x5 = cv2.filter2D(image, -1, gaussian_kernel)
show_image_with_filter(gaussian_blur_5x5, '5x5 Gaussian Blur')

# Terapkan 21x21 Gaussian Blur
gaussian_blur_21x21 = cv2.filter2D(image, -1, gaussian_kernel_21)
show_image_with_filter(gaussian_blur_21x21, '21x21 Gaussian Blur')
