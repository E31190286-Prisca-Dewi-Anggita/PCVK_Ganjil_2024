# %% [markdown]
# <a href="https://colab.research.google.com/github/E31190286-Prisca-Dewi-Anggita/PCVK_Ganjil_2024/blob/main/Praktikum1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import cv2 as cv
from google.colab.patches import cv2_imshow  # for image display
from skimage import io
from skimage import transform
from PIL import Image
import matplotlib.pylab as plt

# %%
urls = [
    "https://iiif.lib.ncsu.edu/iiif/0052574/full/800,/0/default.jpg",
    "https://iiif.lib.ncsu.edu/iiif/0016007/full/800,/0/default.jpg",
    "https://scontent.fmlg16-1.fna.fbcdn.net/v/t39.30808-6/311664281_184471900759664_5273547538134638512_n.jpg?_nc_cat=110&ccb=1-7&_nc_sid=6ee11a&_nc_eui2=AeFRpibSGz_yzJEigszyOlPB82OE9VZmDc7zY4T1VmYNzpOnRSal__kIXtvfSVVZJVof6ccKiIELP3XI_dX57Sxl&_nc_ohc=yQ55p18DW2AQ7kNvgF7iJCb&_nc_ht=scontent.fmlg16-1.fna&_nc_gid=ASmETikOX5OfxDmQ1e39hTm&oh=00_AYAfI3e8naTTbFc-PZvT1JNL5EPrC5cWi8FTQKeuc3NOiQ&oe=670AF81D"
]

# Read and display images
# Loop through each URL image, some images may be stored in a list
for url in urls:
    image = io.imread(url)  # read image
    image = cv.resize(image, (0, 0), fx=0.5, fy=0.5)  # resize to half size
    image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)  # convert color to RGB
    final_frame = cv.hconcat((image, image_2))  # concatenate images
    cv2_imshow(final_frame)  # show image
    print('\n')
# Out:
# <PIL.Image.Image image mode=RGB size=800x276>
# <PIL.Image.Image image mode=RGB size=800x286>
# <PIL.Image.Image image mode=RGB size=474x237>

# %%
tinggi = image_2.shape[0]
lebar = image_2.shape[1]
print("Resolusi image: tinggi x lebar =", tinggi, "x", lebar)
cv2_imshow(image_2)
# Out:
# Resolusi image: tinggi x lebar = 237 x 237
# <PIL.Image.Image image mode=RGB size=237x237>

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

# Draw horizontal line in the middle
for y in range(lebar):
    image_3[int((tinggi) / 2), y] = [255, 255, 255]

# Concatenate images and display
final_frame = cv.hconcat([image_2, image_3])
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=474x237>

# %% [markdown]
# Google Collaboratory, atau Google Colab, adalah alat berbasis cloud yang gratis. Dirancang menggunakan lingkungan Jupyter, Google Colab mendukung berbagai pustaka yang diperlukan dalam pengembangan Kecerdasan Buatan (AI). Pengguna dapat menulis dan menjalankan Python di browser (seperti Chrome, Firefox, dan Safari) tanpa perlu konfigurasi tambahan, mengakses GPU secara gratis, serta berbagi kode dengan mudah untuk kolaborasi tim. Kode yang ditulis dapat dieksekusi, disimpan, dan dibagikan melalui Google Drive, tanpa perlu mengunduh installer, karena semua proses berlangsung di cloud. Selain itu, Google Colab juga menyediakan pustaka bawaan yang memperluas fungsionalitas Python.
#
# Beberapa pustaka yang umum digunakan adalah:
# - **Matplotlib**: untuk menampilkan grafik atau citra.
# - **OpenCV**: untuk pengolahan citra, termasuk membaca, menampilkan, dan memodifikasi citra.
# - **NumPy**: untuk operasi pada array atau matriks, sering dipakai dalam pengolahan data gambar.
#
# Penggunaan pustaka-pustaka ini tidak wajib dalam setiap langkah praktikum, melainkan disesuaikan dengan kebutuhan spesifik pengolahan citra.
#
# Tujuan dari pengolahan citra mencakup membaca citra, mengubah ukurannya, mengonversi citra berwarna ke format RGB, serta menggabungkan citra asli dan hasil konversi. Jika langkah-langkah ini terlewat, hasil citra mungkin tidak sesuai dengan yang diharapkan, seperti ukuran yang tidak berubah atau format yang salah.
#
# Nilai [255, 255, 255] melambangkan warna putih dalam format RGB, di mana 255 adalah nilai maksimum untuk setiap channel (Merah, Hijau, Biru). Kode ini digunakan untuk menentukan warna putih pada piksel tertentu dalam citra.
#
# Pixel adalah unit terkecil dalam citra digital. Resolusi gambar merujuk pada jumlah pixel dalam sebuah citra; semakin banyak pixel, semakin tinggi resolusinya. Gambar dengan resolusi tinggi akan menghasilkan detail yang lebih baik, karena ada lebih banyak informasi visual dalam setiap area kecil.

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

# Draw horizontal line in the middle
for x in range(lebar):  # Iterate over the width
    image_3[x, int(lebar / 2)] = [255, 255, 255]

# Concatenate images and display
final_frame = cv.hconcat([image_2, image_3])
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=474x237>

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

# Draw diagonal line from top-left to bottom-right
for i in range(min(tinggi, lebar)):
    image_3[i, i] = [255, 255, 255]  # Diagonal line
    image_3[i, lebar - i - 1] = [255, 255, 255]

# Concatenate images and display
final_frame = cv.hconcat([image_2, image_3])
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=474x237>

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

# Draw shorter horizontal line in the middle (half the width)
start_y = int(lebar / 4)  # Starting point of the line
end_y = int(3 * lebar / 4)  # End point of the line

for y in range(start_y, end_y):
    image_3[int(tinggi / 2), y] = [255, 255, 255]

# Concatenate images and display
final_frame = cv.hconcat([image_2, image_3])
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=474x237>

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

# Draw a random white box (with specified top-left and bottom-right corners)
start_x_box = int(lebar / 3)
start_y_box = int(tinggi / 3)
end_x_box = start_x_box + 50  # Width of the box
end_y_box = start_y_box + 50  # Height of the box

for x in range(start_x_box, end_x_box):
    for y in range(start_y_box, end_y_box):
        image_3[y, x] = [255, 255, 255]  # White pixel

# Concatenate images and display
final_frame = cv.hconcat([image_2, image_3])
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=474x237>

# %%
urls = [
    "https://tangselife.com/wp-content/uploads/2024/03/2024-03-06-1.jpg"]

# Read and display images
# Loop through each URL image, some images may be stored in a list
for url in urls:
    image = io.imread(url)  # read image
    image = cv.resize(image, (0, 0), fx=0.5, fy=0.5)  # resize to half size
    image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
    final_frame = cv.hconcat((image))
    cv2_imshow(image_2)  # show image
    print('\n')
# Out:
# <PIL.Image.Image image mode=RGB size=500x318>

# %%
urls = [
    "https://tangselife.com/wp-content/uploads/2024/03/2024-03-06-1.jpg"
]

# Loop through each URL image
for url in urls:
    image = io.imread(url)  # Read the image
    image = cv.resize(image, (0, 0), fx=0.5, fy=0.5)  # Resize to half size
    image = cv.cvtColor(image, cv.COLOR_BGR2RGB)
    # Define the coordinates for the areas to cover (example coordinates)
    # Adjust these values based on the actual position of NIK and name on the ID card
    # Format: (start_x, start_y, end_x, end_y)
    nik_area = (120, 50, 350, 75)  # Coordinates for the NIK area
    name_area = (150, 100, 350, 115)  # Coordinates for the name area

    # Cover the NIK area with a white rectangle
    cv.rectangle(image, (nik_area[0], nik_area[1]), (nik_area[2], nik_area[3]), (255, 20, 255), -1)

    # Cover the name area with a white rectangle
    cv.rectangle(image, (name_area[0], name_area[1]), (name_area[2], name_area[3]), (65, 255, 255), -1)

    # Show the modified image
    cv2_imshow(image)  # Display the image with covered areas
    print('\n')
    break  # Exit after the first image
# Out:
# <PIL.Image.Image image mode=RGB size=500x318>
